# %%
def RGB2HSV(image):
    for i, _ in enumerate(image):
        for j, _ in enumerate(image[i]):
            r = image[i][j][0] / 255
            g = image[i][j][1] / 255
            b = image[i][j][2] / 255

            cmax = max(r, g, b)
            cmin = min(r, g, b)
            d = cmax - cmin

            h = 0
            if cmax == r:
                h = 60 * (((g - b) / d) % 6)
            elif cmax == g:
                h = 60 * (((b - r) / d) + 2)
            elif cmax == b:
                h = 60 * (((r - g) / d) + 4)

            v = cmax

            if cmax:
                s = d / cmax
            else:
                s = 0
            
            image[i][j][0] = h / 2
            image[i][j][1] = s * 255
            image[i][j][2] = v * 255
    
    return image.astype(int)

# %%
from skimage import io

# %%
img = io.imread('dog1.jpg')
img.shape, io.imshow(img)
# Out:
# ((1280, 1920, 3), <matplotlib.image.AxesImage at 0x23b198d06d0>)

# %%
new_img = RGB2HSV(img)
# Out:
# C:\Users\Denny\AppData\Local\Temp/ipykernel_11800/2818252991.py:14: RuntimeWarning: invalid value encountered in double_scalars
#   h = 60 * (((g - b) / d) % 6)

# %%
new_img
# Out:
# array([[[112,  18, 166],
#         [112,  18, 165],
#         [112,  18, 166],
#         ...,
#         [122,  63,  56],
#         [122,  63,  56],
#         [122,  63,  56]],
#
#        [[112,  18, 168],
#         [112,  18, 167],
#         [112,  18, 167],
#         ...,
#         [122,  63,  56],
#         [122,  64,  55],
#         [122,  66,  54]],
#
#        [[112,  18, 168],
#         [112,  18, 168],
#         [112,  18, 168],
#         ...,
#         [122,  64,  55],
#         [122,  66,  54],
#         [122,  67,  53]],
#
#        ...,
#
#        [[112,  17, 173],
#         [112,  17, 173],
#         [112,  17, 173],
#         ...,
#         [110,  36, 140],
#         [111,  36, 139],
#         [111,  36, 139]],
#
#        [[112,  17, 174],
#         [112,  17, 174],
#         [112,  17, 174],
#         ...,
#         [110,  36, 141],
#         [110,  36, 141],
#         [111,  36, 138]],
#
#        [[112,  17, 175],
#         [112,  17, 175],
#         [112,  17, 175],
#         ...,
#         [111,  35, 143],
#         [111,  35, 143],
#         [111,  36, 139]]])

# %%
io.imshow(new_img)
# Out:
# C:\Users\Denny\AppData\Local\Programs\Python\Python39\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:150: UserWarning: Low image data range; displaying image with stretched contrast.
#   lo, hi, cmap = _get_display_range(image)
